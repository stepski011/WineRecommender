# %% [markdown]
# This quickstart guide explains how to join two tables A and B using TF-IDF
# similarity measure. First, you need to import the required packages
# as follows (if you have installed **py_stringsimjoin** it will
# automatically install the dependencies **py_stringmatching** and **pandas**):

# %%
# Import libraries
import py_stringsimjoin as ssj
import py_stringmatching as sm
import pandas as pd
import os
import sys

# %%
print('python version: ' + sys.version)
print('py_stringsimjoin version: ' + ssj.__version__)
print('py_stringmatching version: ' + sm.__version__)
print('pandas version: ' + pd.__version__)
# Out:
# python version: 3.10.1 (tags/v3.10.1:2cd268a, Dec  6 2021, 19:10:37) [MSC v.1929 64 bit (AMD64)]
# py_stringsimjoin version: 0.1.0
# py_stringmatching version: 0.4.0
# pandas version: 1.3.4

# %% [markdown]
# Joining two tables using TD-IDF measure typically consists of six steps:
# 1. Loading the input tables
# 2. Profiling the tables
# 3. Creating a tokenizer
# 4. Applying overlap filter
# 5. Creating the corpus for TF-IDF matcher
# 6. Applying the TF-IDF matcher

# %% [markdown]
# # 1. Loading the input tables

# %% [markdown]
# We begin by loading the two tables. For the purpose of this
# guide, we use the books dataset that comes with the package.

# %%
# construct the path of the tables to be loaded. Since we are loading a 
# dataset from the package, we need to access the data from the path 
# where the package is installed. If you need to load your own data, you can directly
# provide your table path to the read_csv command.

table_A_path = "C:/Users/zoran/Desktop/W1.csv"
table_B_path = "C:/Users/zoran/Desktop/W2.csv"

# %%
# Load csv files as dataframes. Since we are reading a compressed csv file, 
# we provide the compression argument. If you are reading an uncompressed 
# csv file, you should not specify the compression argument.

A = pd.read_csv(table_A_path)
B = pd.read_csv(table_B_path)
print('Number of records in A: ' + str(len(A)))
print('Number of records in B: ' + str(len(B)))
# Out:
# Number of records in A: 814
# Number of records in B: 143

# %%
A.head(1)
# Out:
#    ID  \
# 0   1
#
#                                                                            Name:  \
# 0     Château Sansonnet   2019 Château Sansonnet Saint Emilion Grand Cru Classé
#
#                                                          Hersteller:  \
# 0   Château Sansonnet, 1, lieu-dit Sansonnet, F-33330 Saint Emilion
#
#   Erzeugnis aus:                    Region:      Wein: Jahrgang:  \
# 0    Frankreich    Bordeaux, Saint-Emilion    Rotwein       2019
#
#                                                 Rebsorte: Qualität:  \
# 0   85% Merlot, 8% Cabernet Franc, 7% Cabernet Sauvignon       AOC
#
#   Alkohol in %:  ... Herstellung: Dekantieren: Säure g/l: Restzucker g/l:  \
# 0         13.5   ...          NaN          NaN        NaN             NaN
#
#   Produkt aus biologischem Anbau: Biokontrollstelle: Diverses: Zutaten:  \
# 0                             NaN                NaN       NaN      NaN
#
#   Verkäufer:  \
# 0          1
#
#                                                                                      Verkostungsnotiz:
# 0   Lisa Perrotti-Brown, Wine Advocate, Juni 2020: „Opaque garnet-purple in color, the 2019 Sansonn...
#
# [1 rows x 31 columns]

# %%
B.head(1)
# Out:
#    ID  \
# 0   1
#
#                                                                        Name:  \
# 0  2016 Cascina Castlèt Passum Barbera d'Asti D.O.C.G. Superiore 1,5l Magnum
#
#        Hersteller: Erzeugnis aus:  Region:    Wein:  Jahrgang: Rebsorte:  \
# 0  Cascina Castlet        Italien  Piemont  Rotwein     2016.0   Barbera
#
#    Qualität:  Alkohol in %:  ... Herstellung:  Dekantieren:  Säure g/l:  \
# 0        NaN            NaN  ...          NaN           NaN         NaN
#
#    Restzucker g/l:  Produkt aus biologischem Anbau:  Biokontrollstelle:  \
# 0              NaN                              NaN                 NaN
#
#    Diverses: Zutaten:  Verkäufer:  \
# 0        NaN      NaN           2
#
#                                                                                      Verkostungsnotiz:
# 0  Dieser Barbera steht in einer Reihe mit Barolo und Barbaresco. Ein Triumph der traditionellen ro...
#
# [1 rows x 31 columns]

# %% [markdown]
# # 2. Profiling the tables

# %% [markdown]
# Before performing the join, we may want to profile the tables to
# know about the characteristics of the attributes. This can help identify:
#
# a) unique attributes in the table which can be used as key attribute when performing
#    the join. A key attribute is needed to uniquely identify a tuple.
#
# b) the number of missing values present in each attribute. This can
#    help you in deciding the attribute on which to perform the join.
#    For example, an attribute with a lot of missing values may not be a good
#    join attribute. Further, based on the missing value information you
#    need to decide on how to handle missing values when performing the join
#
# You can profile the attributes in a table using the following command:

# %%
# profile attributes in table A
ssj.profile_table_for_join(A)
# Out:
#                                 Unique values Missing values  \
# Attribute
# ID                               814 (100.0%)       0 (0.0%)
# Name:                            811 (99.63%)       0 (0.0%)
# Hersteller:                      164 (20.15%)       0 (0.0%)
# Erzeugnis aus:                     10 (1.23%)       0 (0.0%)
# Region:                            64 (7.86%)       0 (0.0%)
# Wein:                               9 (1.11%)      2 (0.25%)
# Jahrgang:                          40 (4.91%)      8 (0.98%)
# Rebsorte:                        141 (17.32%)     36 (4.42%)
# Qualität:                        113 (13.88%)      2 (0.25%)
# Alkohol in %:                      39 (4.79%)      5 (0.61%)
# Geschmack:                         11 (1.35%)      4 (0.49%)
# Allergene:                          6 (0.74%)       0 (0.0%)
# Ausbauart:                        96 (11.79%)   192 (23.59%)
# Trinktemperatur in °C:             19 (2.33%)      5 (0.61%)
# Trinkempfehlung:                 164 (20.15%)   179 (21.99%)
# Verschluß:                         27 (3.32%)   330 (40.54%)
# Auszeichnungen:                    47 (5.77%)    118 (14.5%)
# Paßt zu:                         123 (15.11%)   588 (72.24%)
# Lage:                            108 (13.27%)   618 (75.92%)
# Boden:                           125 (15.36%)    512 (62.9%)
# Essen:                           107 (13.14%)   576 (70.76%)
# Herstellung:                     113 (13.88%)   565 (69.41%)
# Dekantieren:                       30 (3.69%)    429 (52.7%)
# Säure g/l:                        89 (10.93%)   703 (86.36%)
# Restzucker g/l:                    21 (2.58%)   784 (96.31%)
# Produkt aus biologischem Anbau:    28 (3.44%)   747 (91.77%)
# Biokontrollstelle:                 15 (1.84%)   714 (87.71%)
# Diverses:                          20 (2.46%)   734 (90.17%)
# Zutaten:                            7 (0.86%)   805 (98.89%)
# Verkäufer:                          1 (0.12%)       0 (0.0%)
# Verkostungsnotiz:                538 (66.09%)   240 (29.48%)
#
#                                                                                  Comments
# Attribute
# ID                                         This attribute can be used as a key attribute.
# Name:
# Hersteller:
# Erzeugnis aus:
# Region:
# Wein:                               Joining on this attribute will ignore 2 (0.25%) rows.
# Jahrgang:                           Joining on this attribute will ignore 8 (0.98%) rows.
# Rebsorte:                          Joining on this attribute will ignore 36 (4.42%) rows.
# Qualität:                           Joining on this attribute will ignore 2 (0.25%) rows.
# Alkohol in %:                       Joining on this attribute will ignore 5 (0.61%) rows.
# Geschmack:                          Joining on this attribute will ignore 4 (0.49%) rows.
# Allergene:
# Ausbauart:                       Joining on this attribute will ignore 192 (23.59%) rows.
# Trinktemperatur in °C:              Joining on this attribute will ignore 5 (0.61%) rows.
# Trinkempfehlung:                 Joining on this attribute will ignore 179 (21.99%) rows.
# Verschluß:                       Joining on this attribute will ignore 330 (40.54%) rows.
# Auszeichnungen:                   Joining on this attribute will ignore 118 (14.5%) rows.
# Paßt zu:                         Joining on this attribute will ignore 588 (72.24%) rows.
# Lage:                            Joining on this attribute will ignore 618 (75.92%) rows.
# Boden:                            Joining on this attribute will ignore 512 (62.9%) rows.
# Essen:                           Joining on this attribute will ignore 576 (70.76%) rows.
# Herstellung:                     Joining on this attribute will ignore 565 (69.41%) rows.
# Dekantieren:                      Joining on this attribute will ignore 429 (52.7%) rows.
# Säure g/l:                       Joining on this attribute will ignore 703 (86.36%) rows.
# Restzucker g/l:                  Joining on this attribute will ignore 784 (96.31%) rows.
# Produkt aus biologischem Anbau:  Joining on this attribute will ignore 747 (91.77%) rows.
# Biokontrollstelle:               Joining on this attribute will ignore 714 (87.71%) rows.
# Diverses:                        Joining on this attribute will ignore 734 (90.17%) rows.
# Zutaten:                         Joining on this attribute will ignore 805 (98.89%) rows.
# Verkäufer:
# Verkostungsnotiz:                Joining on this attribute will ignore 240 (29.48%) rows.

# %%
# profile attributes in table B
ssj.profile_table_for_join(B)
# Out:
#                                 Unique values Missing values  \
# Attribute
# ID                               143 (100.0%)       0 (0.0%)
# Name:                             137 (95.8%)       0 (0.0%)
# Hersteller:                        12 (8.39%)    67 (46.85%)
# Erzeugnis aus:                       5 (3.5%)       3 (2.1%)
# Region:                           22 (15.38%)       6 (4.2%)
# Wein:                              10 (6.99%)       3 (2.1%)
# Jahrgang:                          13 (9.09%)    76 (53.15%)
# Rebsorte:                         61 (42.66%)       7 (4.9%)
# Qualität:                            1 (0.7%)   143 (100.0%)
# Alkohol in %:                        1 (0.7%)   143 (100.0%)
# Geschmack:                           7 (4.9%)    67 (46.85%)
# Allergene:                           1 (0.7%)   143 (100.0%)
# Ausbauart:                           1 (0.7%)   143 (100.0%)
# Trinktemperatur in °C:               1 (0.7%)   143 (100.0%)
# Trinkempfehlung:                     1 (0.7%)   143 (100.0%)
# Verschluß:                           1 (0.7%)   143 (100.0%)
# Auszeichnungen:                      1 (0.7%)   143 (100.0%)
# Paßt zu:                          40 (27.97%)    73 (51.05%)
# Lage:                                1 (0.7%)   143 (100.0%)
# Boden:                               1 (0.7%)   143 (100.0%)
# Essen:                               1 (0.7%)   143 (100.0%)
# Herstellung:                         1 (0.7%)   143 (100.0%)
# Dekantieren:                         1 (0.7%)   143 (100.0%)
# Säure g/l:                           1 (0.7%)   143 (100.0%)
# Restzucker g/l:                      1 (0.7%)   143 (100.0%)
# Produkt aus biologischem Anbau:      1 (0.7%)   143 (100.0%)
# Biokontrollstelle:                   1 (0.7%)   143 (100.0%)
# Diverses:                            1 (0.7%)   143 (100.0%)
# Zutaten:                             1 (0.7%)   143 (100.0%)
# Verkäufer:                           1 (0.7%)       0 (0.0%)
# Verkostungsnotiz:                125 (87.41%)       0 (0.0%)
#
#                                                                                  Comments
# Attribute
# ID                                         This attribute can be used as a key attribute.
# Name:
# Hersteller:                       Joining on this attribute will ignore 67 (46.85%) rows.
# Erzeugnis aus:                       Joining on this attribute will ignore 3 (2.1%) rows.
# Region:                              Joining on this attribute will ignore 6 (4.2%) rows.
# Wein:                                Joining on this attribute will ignore 3 (2.1%) rows.
# Jahrgang:                         Joining on this attribute will ignore 76 (53.15%) rows.
# Rebsorte:                            Joining on this attribute will ignore 7 (4.9%) rows.
# Qualität:                        Joining on this attribute will ignore 143 (100.0%) rows.
# Alkohol in %:                    Joining on this attribute will ignore 143 (100.0%) rows.
# Geschmack:                        Joining on this attribute will ignore 67 (46.85%) rows.
# Allergene:                       Joining on this attribute will ignore 143 (100.0%) rows.
# Ausbauart:                       Joining on this attribute will ignore 143 (100.0%) rows.
# Trinktemperatur in °C:           Joining on this attribute will ignore 143 (100.0%) rows.
# Trinkempfehlung:                 Joining on this attribute will ignore 143 (100.0%) rows.
# Verschluß:                       Joining on this attribute will ignore 143 (100.0%) rows.
# Auszeichnungen:                  Joining on this attribute will ignore 143 (100.0%) rows.
# Paßt zu:                          Joining on this attribute will ignore 73 (51.05%) rows.
# Lage:                            Joining on this attribute will ignore 143 (100.0%) rows.
# Boden:                           Joining on this attribute will ignore 143 (100.0%) rows.
# Essen:                           Joining on this attribute will ignore 143 (100.0%) rows.
# Herstellung:                     Joining on this attribute will ignore 143 (100.0%) rows.
# Dekantieren:                     Joining on this attribute will ignore 143 (100.0%) rows.
# Säure g/l:                       Joining on this attribute will ignore 143 (100.0%) rows.
# Restzucker g/l:                  Joining on this attribute will ignore 143 (100.0%) rows.
# Produkt aus biologischem Anbau:  Joining on this attribute will ignore 143 (100.0%) rows.
# Biokontrollstelle:               Joining on this attribute will ignore 143 (100.0%) rows.
# Diverses:                        Joining on this attribute will ignore 143 (100.0%) rows.
# Zutaten:                         Joining on this attribute will ignore 143 (100.0%) rows.
# Verkäufer:
# Verkostungsnotiz:

# %% [markdown]
# Based on the profile output, we find that the 'Title' attribute in both tables does
# not contain any missing values. Hence, for the purpose of this guide, we will now
# join tables A and B on 'Title' attribute using TF-IDF measure. Next, we need to decide
# on what threshold to use for the join. For this guide, we will use a threshold of 0.5.
# Specifically, the join will now find tuple pairs from A and B such that the TF-IDF score
# over the 'Title' attributes is at least 0.5.
#
# Naively, performing the join will involve enumerating the cartesian product
# AxB (3022 x 3099 = 9365178) and computing TF-IDF score for every pair. But, this can be
# very time consuming. Hence, we can optimize by first appplying an overlap filter over tables
# A and B to find pairs sharing at least one token in the 'Title' attribute. The intuition here
# is that in order for TF-IDF score to be above zero, there must be at least one common token
# between the attributes. Finally, we apply the TF-IDF measure over the candidate pairs
# to obtain the join output.

# %% [markdown]
# # 3. Creating a tokenizer

# %% [markdown]
# Since TF-IDF measure treats input strings as bags of tokens, we
# need to select a tokenizer which can be used to tokenize each string
# into a bag of tokens. Currently, we support tokenizers from **py_stringmatching**
# package which provides five different tokenizer types: alphabetical tokenizer,
# alphanumeric tokenizer, delimiter-based tokenizer, qgram tokenizer,
# and whitespace tokenizer.
#
# For the purpose of this guide, we will use a whitespace tokenizer. Once
# we have selected a tokenizer type, we need to create a tokenizer object as
# shown below:

# %%
# create whitespace tokenizer for tokenizing 'Title' attribute
ws = sm.WhitespaceTokenizer()

ws.tokenize('The Maze Runner Series Complete Collection')
# Out:
# ['The', 'Maze', 'Runner', 'Series', 'Complete', 'Collection']

# %% [markdown]
# # 4. Applying overlap filter

# %% [raw]
# Next, we need to create and apply overlap filter over tables A and B to obtain a candidate set of pairs C.

# %%
# create overlap filter with whitespace tokenizer and threshold of 1. 
of = ssj.OverlapFilter(ws, 5) 

# apply overlap filter to tables A and B to find tuple pairs 
# sharing at least 1 token in Title attribute
C = of.filter_tables(A, B, 'ID', 'ID', 'Name:', 'Name:', n_jobs=-1)
# Out:
# c:\projects\data integration\desktop\lib\site-packages\py_stringsimjoin\utils\validation.py:28: FutureWarning: The pandas.np module is deprecated and will be removed from pandas in a future version. Import numpy directly instead
#   if attr_type != pd.np.object:
# c:\projects\data integration\desktop\lib\site-packages\py_stringsimjoin\utils\generic_helper.py:76: FutureWarning: In a future version of pandas all arguments of DataFrame.dropna will be keyword-only
#   projected_dataframe = dataframe[proj_attrs].dropna(0,

# %%
len(C)
# Out:
# 86

# %%
C.head(5)
# Out:
#    _id l_ID r_ID
# 0    0  201   13
# 0    1  161   22
# 1    2  204   22
# 0    3   33   41
# 1    4  201   41

# %% [markdown]
# If you want to include pairs with missing value in the output,
# you need to set the **allow_missing** flag to True when creating
# the overlap filter as shown below:

# %%
of = ssj.OverlapFilter(ws, 1, allow_missing=True)

# %% [markdown]
# Now, when you apply the filter, pairs with missing values will also
# be included in the output.

# %% [markdown]
# # 5. Creating the corpus for TF-IDF matcher

# %% [markdown]
# The next step is to create the corpus required for TF-IDF measure.
# Specifically, the corpus consists of the list of tokens in the 'Title'
# attribute. The corpus can be created as follows:

# %%
# create a list of tokens
A_tokens = A['Name:'].apply(ws.tokenize).tolist()
B_tokens = B['Name:'].apply(ws.tokenize).tolist()

# merge both the lists of tokens to create the corpus
corpus = A_tokens + B_tokens

# %% [markdown]
# # 6. Applying the TF-IDF matcher

# %% [markdown]
# Finally, you need to create and apply the TF-IDF matcher as shown below:

# %%
# create tf-idf object with the generated corpus
tfidf = sm.TfIdf(corpus, dampen=True)

# %%
# apply the matcher with a threshold of 0.5. This will find pairs from C 
# with TF-IDF score >= 0.5. Setting n_jobs=-1 exploits all CPU cores available.

output_pairs = ssj.apply_matcher(C, 'l_ID', 'r_ID', A, B, 'ID', 'ID', 'Name:', 'Name:',
                                 ws, tfidf.get_sim_score, 0.5, 
                                 l_out_attrs=['Name:'], r_out_attrs=['Name:'], n_jobs=-1)

# %%
len(output_pairs)
# Out:
# 3

# %%
output_pairs.head()
# Out:
#   _id l_ID r_ID  \
# 0  74  713  101
# 0  75  692  103
# 1  84  713  140
#
#                                                                         l_Name:  \
# 0               Weingut K.-H. Milch   2020 Blanc de Noir Spätburgunder trocken
# 0     Weingut Schloss Lieser   2019 Riesling Spätlese Piesporter Goldtröpfchen
# 1               Weingut K.-H. Milch   2020 Blanc de Noir Spätburgunder trocken
#
#                                                                  r_Name:  \
# 0           2019 Weingut Hain Spätburgunder Blanc de Noir Q.b.A. trocken
# 0  2019 Weingut Hain Piesporter Goldtröpfchen Riesling Kabinett feinherb
# 1           2019 Weingut Hain Spätburgunder Blanc de Noir Q.b.A. trocken
#
#    _sim_score
# 0    0.534284
# 0    0.510260
# 1    0.534284

# %% [markdown]
# If you want to include pairs with missing value in the output,
# you need to set the **allow_missing** flag to True in the
# **apply_matcher** method.
